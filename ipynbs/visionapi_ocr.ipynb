# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64, json

# %%
# Replace the subscription_key string value with your valid subscription key.
subscription_key = 'e83441cd941147e8805903732ec6ed18'
uri_base = 'westcentralus.api.cognitive.microsoft.com'

# %%
headers = {
    # Request headers.
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': subscription_key,
}

# %%
params = urllib.parse.urlencode({
    # Request parameters. All of them are optional.
    'language' : 'fr'
})

# %%
body = "{'url':'https://4.bp.blogspot.com/-XFH0rVo4R0o/VkS4pwfWQjI/AAAAAAAAAhQ/lHqSjLM2vso/s640/pommard-premier-cru.jpg'}"

# %% [markdown]
# ![Wine.jpg](attachment:Wine.jpg)

# %%
try:
    # Execute the REST API call and get the response.
    conn = http.client.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
    conn.request("POST", "/vision/v1.0/OCR?%s" % params, body, headers)
    response = conn.getresponse()
    data = response.read()

    # 'data' contains the JSON data. The following formats the JSON data for display.
    parsed = json.loads(data)
    print ("Response:")
    print (json.dumps(parsed, sort_keys=True, indent=2))
    conn.close()

except Exception as e:
    print('Error:')
    print(e)
# Out:
# Response:
# {
#   "language": "fr",
#   "orientation": "Up",
#   "regions": [
#     {
#       "boundingBox": "90,189,469,222",
#       "lines": [
#         {
#           "boundingBox": "155,189,336,11",
#           "words": [
#             {
#               "boundingBox": "155,189,76,11",
#               "text": "GRAND"
#             },
#             {
#               "boundingBox": "250,189,36,10",
#               "text": "VIN"
#             },
#             {
#               "boundingBox": "307,189,23,11",
#               "text": "DE"
#             },
#             {
#               "boundingBox": "350,189,7,11",
#               "text": "B"
#             },
#             {
#               "boundingBox": "365,189,27,11",
#               "text": "ou"
#             },
#             {
#               "boundingBox": "400,189,42,11",
#               "text": "RGO"
#             },
#             {
#               "boundingBox": "451,190,40,10",
#               "text": "GNE"
#             }
#           ]
#         },
#         {
#           "boundingBox": "90,226,469,42",
#           "words": [
#             {
#               "boundingBox": "90,226,272,41",
#               "text": "POMMARD"
#             },
#             {
#               "boundingBox": "383,227,52,40",
#               "text": "1ER"
#             },
#             {
#               "boundingBox": "453,227,106,41",
#               "text": "CRU"
#             }
#           ]
#         },
#         {
#           "boundingBox": "158,294,330,19",
#           "words": [
#             {
#               "boundingBox": "158,294,62,19",
#               "text": "CLOS"
#             },
#             {
#               "boundingBox": "232,295,30,18",
#               "text": "DE"
#             },
#             {
#               "boundingBox": "274,295,27,18",
#               "text": "LA"
#             },
#             {
#               "boundingBox": "310,295,178,18",
#               "text": "COMMARAINE"
#             }
#           ]
#         },
#         {
#           "boundingBox": "234,377,175,21",
#           "words": [
#             {
#               "boundingBox": "234,381,81,17",
#               "text": "PIERRE"
#             },
#             {
#               "boundingBox": "325,377,84,21",
#               "text": "ANDR\u00c9"
#             }
#           ]
#         },
#         {
#           "boundingBox": "234,401,176,10",
#           "words": [
#             {
#               "boundingBox": "234,403,15,7",
#               "text": "AU"
#             },
#             {
#               "boundingBox": "254,401,50,9",
#               "text": "CHATEAU"
#             },
#             {
#               "boundingBox": "326,402,44,8",
#               "text": "CORTON"
#             },
#             {
#               "boundingBox": "375,401,35,10",
#               "text": "ANDR\u00c9"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "textAngle": 0.0
# }
